# %% [markdown]
# # Writing Data
#
# Just as there are many ways to read data, we have just as many ways to write data.
#
# In this notebook, we will take a quick peek at how to write data back out to Parquet files.
#
# **Technical Accomplishments:**
# - Writing data to Parquet files

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Getting Started
#
# Run the following cell to configure our "classroom."

# %%
# %run "./Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Initialized classroom variables & functions...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Datasets are already mounted to <b>/mnt/training</b> from <b>wasbs://training@dbtraineastus.blob.core.windows.net/</b>
# Created user-specific database
# Using the database <b style="color:green">aleksei_cherniaev_if_lv_db</b>.
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# All done!

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Writing Data
#
# Let's start with one of our original CSV data sources, **pageviews_by_second.tsv**:

# %%
from pyspark.sql.types import *

csvSchema = StructType([
  StructField("timestamp", StringType(), False),
  StructField("site", StringType(), False),
  StructField("requests", IntegerType(), False)
])

csvFile = "/mnt/training/wikipedia/pageviews/pageviews_by_second.tsv"

csvDF = (spark.read
  .option('header', 'true')
  .option('sep', "\t")
  .schema(csvSchema)
  .csv(csvFile)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now that we have a `DataFrame`, we can write it back out as Parquet files or other various formats.

# %%
fileName = userhome + "/pageviews_by_second.parquet"
print("Output location: " + fileName)

(csvDF.write                       # Our DataFrameWriter
  .option("compression", "snappy") # One of none, snappy, gzip, and lzo
  .mode("overwrite")               # Replace existing files
  .parquet(fileName)               # Write DataFrame to Parquet files
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Output location: dbfs:/user/aleksei.cherniaev@if.lv/pageviews_by_second.parquet
# </div>

# %% [markdown]
# Now that the file has been written out, we can see it in the DBFS:

# %%
display(
  dbutils.fs.ls(fileName)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/aleksei.cherniaev@if.lv/pageviews_by_second.parquet/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/user/aleksei.cherniaev@if.lv/pageviews_by_second.parquet/_committed_4253893252546785505</td><td>_committed_4253893252546785505</td><td>420</td></tr><tr><td>dbfs:/user/aleksei.cherniaev@if.lv/pageviews_by_second.parquet/_started_4253893252546785505</td><td>_started_4253893252546785505</td><td>0</td></tr><tr><td>dbfs:/user/aleksei.cherniaev@if.lv/pageviews_by_second.parquet/part-00000-tid-4253893252546785505-821a1572-e008-4d73-9ad3-6797ed27c0c9-33-1-c000.snappy.parquet</td><td>part-00000-tid-4253893252546785505-821a1572-e008-4d73-9ad3-6797ed27c0c9-33-1-c000.snappy.parquet</td><td>15379959</td></tr><tr><td>dbfs:/user/aleksei.cherniaev@if.lv/pageviews_by_second.parquet/part-00001-tid-4253893252546785505-821a1572-e008-4d73-9ad3-6797ed27c0c9-34-1-c000.snappy.parquet</td><td>part-00001-tid-4253893252546785505-821a1572-e008-4d73-9ad3-6797ed27c0c9-34-1-c000.snappy.parquet</td><td>15753779</td></tr><tr><td>dbfs:/user/aleksei.cherniaev@if.lv/pageviews_by_second.parquet/part-00002-tid-4253893252546785505-821a1572-e008-4d73-9ad3-6797ed27c0c9-35-1-c000.snappy.parquet</td><td>part-00002-tid-4253893252546785505-821a1572-e008-4d73-9ad3-6797ed27c0c9-35-1-c000.snappy.parquet</td><td>15726154</td></tr><tr><td>dbfs:/user/aleksei.cherniaev@if.lv/pageviews_by_second.parquet/part-00003-tid-4253893252546785505-821a1572-e008-4d73-9ad3-6797ed27c0c9-36-1-c000.snappy.parquet</td><td>part-00003-tid-4253893252546785505-821a1572-e008-4d73-9ad3-6797ed27c0c9-36-1-c000.snappy.parquet</td><td>14776555</td></tr></tbody></table></div>

# %% [markdown]
# And lastly we can read that same parquet file back in and display the results:

# %%
display(
  spark.read.parquet(fileName).limit(4)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timestamp</th><th>site</th><th>requests</th></tr></thead><tbody><tr><td>2015-03-30T16:37:18</td><td>mobile</td><td>1456</td></tr><tr><td>2015-03-30T16:51:11</td><td>desktop</td><td>2917</td></tr><tr><td>2015-03-30T17:10:47</td><td>desktop</td><td>3043</td></tr><tr><td>2015-03-30T17:12:39</td><td>mobile</td><td>1440</td></tr></tbody></table></div>

# %% [markdown]
# ## Next steps
#
# Start the next lesson, [Reading Data - Lab]($./6.Reading%20Data%20-%20Lab)
